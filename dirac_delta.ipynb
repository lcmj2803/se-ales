# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Puntos y amplitud
puntos = 10 
amp= np.random.uniform(0.8,1.2,puntos)
t_values=np.zeros(puntos)

plt.figure(figsize=(8,4))
plt.scatter(t_values,amp,color='red',label=r'Puntos para $\delta(t)$')
plt.show()
